# %%
from keras.preprocessing.image import img_to_array
from keras.models import load_model
import numpy as np
import argparse
import imutils
import pickle
import cv2
import os
import matplotlib.pyplot as plt
import skimage.io as io
import pandas as pd
import csv
import re
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
path = "./" #파일경로
sdir = path+'0423_final_crawl/'
porductlist='./final_200424_AllDB.csv'
modelfile='fashion4.model'
labelbinfile='mlb4.pickle'

# %%
num=0
end=50
db=[]
f = open(porductlist,encoding='utf-8')
rdr = csv.reader(f)
# load the trained convolutional neural network and the multi-label
# binarizer
print("[INFO] loading network...")
model = load_model(modelfile)
mlb = pickle.loads(open(labelbinfile, "rb").read())
# classify the input image then find the indexes of the two class
# labels with the *largest* probability
next(rdr)#헤더여부에 따라 사용
for line in rdr:
    if num == end:
        break
    imagefile=sdir+line[11]
    # load the image
    image = cv2.imread(imagefile)
    output = imutils.resize(image, width=400)

    # pre-process the image for classification
    image = cv2.resize(image, (96, 96))
    image = image.astype("float") / 255.0
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)

    print("[INFO] classifying image... filename:"+line[11])
    proba = model.predict(image)[0]
    idxs = np.argsort(proba)[::-1][:14]

    # loop over the indexes of the high confidence class labels

    # show the probabilities for each of the individual labels


    # show the output image
    #cv2.imshow("Output", output)
    #cv2.waitKey(0)
    #I = io.imread(imagefile)
    #plt.imshow(I); plt.axis('off'); plt.show()
    print("{}: {:.2f}%".format(mlb.classes_[0], proba[0] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[18], proba[18] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[8], proba[8] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[1], proba[1] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[6], proba[6] * 100),end='\t\t');print();
    print("{}: {:.2f}%".format(mlb.classes_[9], proba[9] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[19], proba[19] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[10], proba[10] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[2], proba[2] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[5], proba[5] * 100),end='\t\t');print();
    print("{}: {:.2f}%".format(mlb.classes_[21], proba[21] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[15], proba[15] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[12], proba[12] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[11], proba[11] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[4], proba[4] * 100),end='\t\t');print();
    print("{}: {:.2f}%".format(mlb.classes_[20], proba[20] * 100),end='\t\t\t\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[13], proba[13] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[16], proba[16] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[3], proba[3] * 100),end='\t\t');print();
    print("{}: {:.2f}%".format(mlb.classes_[-6], proba[-6] * 100),end='\t\t\t\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[14], proba[14] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[22], proba[22] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[7], proba[7] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[17], proba[17] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[25], proba[25] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[23], proba[23] * 100),end='\t')
    print("{}: {:.2f}%".format(mlb.classes_[-5], proba[-5] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[24], proba[24] * 100),end='\t\t')
    print("{}: {:.2f}%".format(mlb.classes_[-1], proba[-1] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[26], proba[26] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[27], proba[27] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[28], proba[28] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[31], proba[31] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[32], proba[32] * 100),end='\t\t');print();
    print("\t\t\t\t\t\t{}: {:.2f}%".format(mlb.classes_[33], proba[33] * 100),end='\t\t');print();
    db.append(proba)
    num=num+1
    
f.close()
# Out:
# [INFO] loading network...
# [INFO] classifying image... filename:img_11546174870_0.png
# 5부: 0.00%		미니: 11.21%		기하학: 0.00%		7부: 16.91%		green: 0.00%
# 긴팔: 30.59%		미디: 61.19%		도트: 0.00%		A라인: 20.03%		blue: 0.01%
# 반팔: 2.88%		롱: 16.56%		레오파드: 0.00%		랩: 1.09%		black: 0.04%
# 민소매: 37.78%					레터링: 0.03%		머메이드: 2.91%		H라인: 60.95%
# 캐릭터: 0.01%					로고: 0.06%		벌룬: 0.01%		red: 100.00%
# 						무지: 98.69%		언밸런스: 0.26%
# 						스트라이프: 0.05%	캡소매: 1.80%
# 						아가일: 0.00%		플리츠주름: 0.50%
# 						체크: 0.09%
# 						츄리닝: 0.03%
# 						캐릭터: 0.01%
# 						프린트: 5.34%
# 						플라워: 0.06%
# 						플리츠주름: 0.50%
# [INFO] classifying image... filename:img_11546174912_0.png
# 5부: 0.00%		미니: 25.69%		기하학: 0.00%		7부: 8.12%		green: 0.00%
# 긴팔: 26.83%		미디: 18.54%		도트: 0.03%		A라인: 42.04%		blue: 99.97%
# 반팔: 47.97%		롱: 46.98%		레오파드: 0.00%		랩: 2.56%		black: 0.04%
# 민소매: 0.03%					레터링: 0.01%		머메이드: 0.30%		H라인: 36.45%
# 캐릭터: 0.00%					로고: 0.00%		벌룬: 1.67%		red: 0.00%
# 						무지: 98.43%		언밸런스: 0.04%
# ...

# %%
#CSV 로 저장
df=pd.DataFrame(db)
df.to_csv('result4.csv')
